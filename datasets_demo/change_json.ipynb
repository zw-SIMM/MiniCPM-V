# %%
import json
with open("/home/zhangwei/MiniCPM-V/datasets/LLaVA-CC3M-Pretrain-595K/chat.json", 'r') as file:
    data = json.load(file)

data
# Out:
# [{'id': 'GCC_train_002582585',
#   'image': 'GCC_train_002582585.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt',
#     'value': 'olive oil is a healthy ingredient used liberally .'}]},
#  {'id': 'GCC_train_002429825',
#   'image': 'GCC_train_002429825.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': '3d vector deluxe alphabet of randomly rotated thin golden symbols .'}]},
#  {'id': 'GCC_train_000190697',
#   'image': 'GCC_train_000190697.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Share a concise interpretation of the image provided.\n'},
#    {'from': 'gpt',
#     'value': 'weathering -- the physical & chemical breakdown of rocks .'}]},
#  {'id': 'GCC_train_002503829',
#   'image': 'GCC_train_002503829.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt',
#     'value': 'fans interferes with # on a ball hit by # of sports team scoring runs in the eighth inning during game'}]},
#  {'id': 'GCC_train_000530863',
#   'image': 'GCC_train_000530863.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRender a clear and concise summary of the photo.'},
#    {'from': 'gpt', 'value': 'train that takes you around the perimeter'}]},
#  {'id': 'GCC_train_001970366',
#   'image': 'GCC_train_001970366.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt',
#     'value': 'cheers - lettering holiday calligraphy phrase isolated on the background .'}]},
#  {'id': 'GCC_train_001885390',
#   'image': 'GCC_train_001885390.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRender a clear and concise summary of the photo.'},
#    {'from': 'gpt',
#     'value': 'celebrity and organisation founder conquered the mountain peak yesterday'}]},
#  {'id': 'GCC_train_001764002',
#   'image': 'GCC_train_001764002.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nGive a short and clear explanation of the subsequent image.'},
#    {'from': 'gpt',
#     'value': 'bring the water to a boil and leave the lid slightly open to prevent spilling .'}]},
#  {'id': 'GCC_train_002554598',
#   'image': 'GCC_train_002554598.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt',
#     'value': 'grey sofas and circular coffee table on roofed terrace of large villa with a view of the ocean'}]},
#  {'id': 'GCC_train_001948583',
#   'image': 'GCC_train_001948583.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nSummarize the visual content of the image.'},
#    {'from': 'gpt',
#     'value': 'continent gathers oysters on the rocks at low tide along the beautiful coast'}]},
#  {'id': 'GCC_train_000177248',
#   'image': 'GCC_train_000177248.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nProvide a brief description of the given image.'},
#    {'from': 'gpt', 'value': 'organization is synonymous with azaleas .'}]},
#  {'id': 'GCC_train_001032516',
#   'image': 'GCC_train_001032516.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt',
#     'value': 'like the feature wall , ceiling and chandelier'}]},
#  {'id': 'GCC_train_002664280',
#   'image': 'GCC_train_002664280.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nCreate a compact narrative representing the image presented.'},
#    {'from': 'gpt',
#     'value': 'mass marriage ceremony organized for couples .'}]},
#  {'id': 'GCC_train_002448550',
#   'image': 'GCC_train_002448550.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nProvide a brief description of the given image.'},
#    {'from': 'gpt',
#     'value': 'a view of a city , where the flyover was proposed to reduce the increasing traffic on thursday .'}]},
#  {'id': 'GCC_train_000610553',
#   'image': 'GCC_train_000610553.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRelay a brief, clear account of the picture shown.'},
#    {'from': 'gpt',
#     'value': 'person watches the ball right into his glove for football team under 13s .'}]},
#  {'id': 'GCC_train_001912708',
#   'image': 'GCC_train_001912708.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt',
#     'value': 'time lapse clouds moving across the blue sky , tracking shot'}]},
#  {'id': 'GCC_train_000343618',
#   'image': 'GCC_train_000343618.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Summarize the visual content of the image.\n'},
#    {'from': 'gpt',
#     'value': 'conceptual illustration of the teamwork of professionals'}]},
#  {'id': 'GCC_train_000844196',
#   'image': 'GCC_train_000844196.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Share a concise interpretation of the image provided.\n'},
#    {'from': 'gpt',
#     'value': "olympic athlete is seen during the men 's handball preliminary group b match"}]},
#  {'id': 'GCC_train_002164562',
#   'image': 'GCC_train_002164562.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nSummarize the visual content of the image.'},
#    {'from': 'gpt',
#     'value': 'a traditional room complete with mountain views .'}]},
#  {'id': 'GCC_train_000700825',
#   'image': 'GCC_train_000700825.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nDescribe the image concisely.'},
#    {'from': 'gpt',
#     'value': 'politician testifies , before the hearing on federal budget .'}]},
#  {'id': 'GCC_train_001152484',
#   'image': 'GCC_train_001152484.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nProvide a brief description of the given image.'},
#    {'from': 'gpt',
#     'value': 'aerial summer view of village looking up a city is a town'}]},
#  {'id': 'GCC_train_000644518',
#   'image': 'GCC_train_000644518.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Write a terse but informative summary of the picture.\n'},
#    {'from': 'gpt',
#     'value': 'add a salt to boiling water in metal pot on black background , slow motion fps'}]},
#  {'id': 'GCC_train_001846597',
#   'image': 'GCC_train_001846597.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Summarize the visual content of the image.\n'},
#    {'from': 'gpt', 'value': 'religious leadership title met refugees'}]},
#  {'id': 'GCC_train_001887818',
#   'image': 'GCC_train_001887818.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': 'actor attends the premiere to promote the movie psychological thriller film during festival .'}]},
#  {'id': 'GCC_train_001156400',
#   'image': 'GCC_train_001156400.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRelay a brief, clear account of the picture shown.'},
#    {'from': 'gpt',
#     'value': 'colorful pink ice tray a device for ingredient'}]},
#  {'id': 'GCC_train_000592127',
#   'image': 'GCC_train_000592127.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nOffer a succinct explanation of the picture presented.'},
#    {'from': 'gpt', 'value': 'pooch has quite the sense of humor !'}]},
#  {'id': 'GCC_train_001775121',
#   'image': 'GCC_train_001775121.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'a man walks alone on a dock in a mountain lake'}]},
#  {'id': 'GCC_train_000325690',
#   'image': 'GCC_train_000325690.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'cupcakes made to match baby shower cake for a friend .'}]},
#  {'id': 'GCC_train_000417419',
#   'image': 'GCC_train_000417419.jpg',
#   'conversations': [{'from': 'human',
#     'value': "Present a compact description of the photo's key features.\n"},
#    {'from': 'gpt', 'value': 'biological species crawling on a banana leaf'}]},
#  {'id': 'GCC_train_001157703',
#   'image': 'GCC_train_001157703.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nCreate a compact narrative representing the image presented.'},
#    {'from': 'gpt', 'value': 'another chestnut tree i grew from seed .'}]},
#  {'id': 'GCC_train_000591181',
#   'image': 'GCC_train_000591181.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Render a clear and concise summary of the photo.\n'},
#    {'from': 'gpt', 'value': 'aloe vera gel in a bowl'}]},
#  {'id': 'GCC_train_000669874',
#   'image': 'GCC_train_000669874.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': 'a jackal bites the leg of a hyena and runs away'}]},
#  {'id': 'GCC_train_001887540',
#   'image': 'GCC_train_001887540.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Summarize the visual content of the image.\n'},
#    {'from': 'gpt',
#     'value': 'once photosynthesis begins , the plant is called a seedling .'}]},
#  {'id': 'GCC_train_002429753',
#   'image': 'GCC_train_002429753.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRender a clear and concise summary of the photo.'},
#    {'from': 'gpt',
#     'value': 'domesticated camels provide an alternative mode of transport around the ruins'}]},
#  {'id': 'GCC_train_001125212',
#   'image': 'GCC_train_001125212.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nDescribe the image concisely.'},
#    {'from': 'gpt', 'value': 'a man plays with an era cannon'}]},
#  {'id': 'GCC_train_002546113',
#   'image': 'GCC_train_002546113.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nDescribe the image concisely.'},
#    {'from': 'gpt',
#     'value': 'person the psychology of why gray kitchen cabinets are so popular home'}]},
#  {'id': 'GCC_train_002726079',
#   'image': 'GCC_train_002726079.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'music video director and actor at the premiere ofromance film .'}]},
#  {'id': 'GCC_train_002702626',
#   'image': 'GCC_train_002702626.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRelay a brief, clear account of the picture shown.'},
#    {'from': 'gpt',
#     'value': 'breeder were awarded olympic medal for their wonderful exhibit , inside festival , at show .'}]},
#  {'id': 'GCC_train_002697626',
#   'image': 'GCC_train_002697626.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt',
#     'value': 'global dollar in the design of information related to finance .'}]},
#  {'id': 'GCC_train_000449010',
#   'image': 'GCC_train_000449010.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt',
#     'value': 'flower power : actor wore a floral frock to the event'}]},
#  {'id': 'GCC_train_002367664',
#   'image': 'GCC_train_002367664.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Describe the image concisely.\n'},
#    {'from': 'gpt', 'value': 'a photograph of a pheasant'}]},
#  {'id': 'GCC_train_002036038',
#   'image': 'GCC_train_002036038.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Give a short and clear explanation of the subsequent image.\n'},
#    {'from': 'gpt',
#     'value': 'really old painting of a mermaid , still like it though .'}]},
#  {'id': 'GCC_train_000637205',
#   'image': 'GCC_train_000637205.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'company was initially contracted in december to take down controversial monuments , including this - foot statue celebrating military commander'}]},
#  {'id': 'GCC_train_002785219',
#   'image': 'GCC_train_002785219.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt',
#     'value': 'wrap - around kitchen counter with breakfast bar in an apartment'}]},
#  {'id': 'GCC_train_001848993',
#   'image': 'GCC_train_001848993.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt', 'value': 'peanuts on sale at a street market'}]},
#  {'id': 'GCC_train_002794019',
#   'image': 'GCC_train_002794019.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': 'luxury log home has pool table & private outdoor hot tub .'}]},
#  {'id': 'GCC_train_002311916',
#   'image': 'GCC_train_002311916.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': 'actor and magazine editor attend the premiere after party .'}]},
#  {'id': 'GCC_train_002662824',
#   'image': 'GCC_train_002662824.jpg',
#   'conversations': [{'from': 'human',
#     'value': "\nPresent a compact description of the photo's key features."},
#    {'from': 'gpt',
#     'value': 'a big diesel engine depicted in contour lines on graph paper .'}]},
#  {'id': 'GCC_train_002293258',
#   'image': 'GCC_train_002293258.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt', 'value': 'the map as posted in the parking area .'}]},
#  {'id': 'GCC_train_002174279',
#   'image': 'GCC_train_002174279.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nOffer a succinct explanation of the picture presented.'},
#    {'from': 'gpt',
#     'value': 'mare and foal hurry on steppe on a white background'}]},
#  {'id': 'GCC_train_002499670',
#   'image': 'GCC_train_002499670.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt',
#     'value': 'melting ice cubes and spices on a stainless steel surface'}]},
#  {'id': 'GCC_train_001816902',
#   'image': 'GCC_train_001816902.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Share a concise interpretation of the image provided.\n'},
#    {'from': 'gpt', 'value': 'pretty bride in a lace dress'}]},
#  {'id': 'GCC_train_001685772',
#   'image': 'GCC_train_001685772.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nCreate a compact narrative representing the image presented.'},
#    {'from': 'gpt',
#     'value': 'a black baseball cap bears the name of the singer and her latest effort'}]},
#  {'id': 'GCC_train_000255480',
#   'image': 'GCC_train_000255480.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRelay a brief, clear account of the picture shown.'},
#    {'from': 'gpt',
#     'value': 'retro card with a flying balloon on a blue watercolor background .'}]},
#  {'id': 'GCC_train_002209917',
#   'image': 'GCC_train_002209917.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Give a short and clear explanation of the subsequent image.\n'},
#    {'from': 'gpt', 'value': 'outdoor living space with a brick fireplace'}]},
#  {'id': 'GCC_train_001711524',
#   'image': 'GCC_train_001711524.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Write a terse but informative summary of the picture.\n'},
#    {'from': 'gpt', 'value': 'an old dinghy rests upon a muddy shore'}]},
#  {'id': 'GCC_train_000931257',
#   'image': 'GCC_train_000931257.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt', 'value': 'black and red poker chips in the background'}]},
#  {'id': 'GCC_train_000988304',
#   'image': 'GCC_train_000988304.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nSummarize the visual content of the image.'},
#    {'from': 'gpt',
#     'value': 'a huge pile of paperwork on a desk beside a laptop computer'}]},
#  {'id': 'GCC_train_002090748',
#   'image': 'GCC_train_002090748.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': 'presents the new watch for men calledsoftware with human language'}]},
#  {'id': 'GCC_train_001026635',
#   'image': 'GCC_train_001026635.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt',
#     'value': 'a secure car park in the area with metal doors for country'}]},
#  {'id': 'GCC_train_002576187',
#   'image': 'GCC_train_002576187.jpg',
#   'conversations': [{'from': 'human',
#     'value': "\nPresent a compact description of the photo's key features."},
#    {'from': 'gpt', 'value': 'a bowl of stew with buttered bread .'}]},
#  {'id': 'GCC_train_001879962',
#   'image': 'GCC_train_001879962.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Describe the image concisely.\n'},
#    {'from': 'gpt',
#     'value': 'a morning time capture with a group of seagulls on the beach .'}]},
#  {'id': 'GCC_train_002694404',
#   'image': 'GCC_train_002694404.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nDescribe the image concisely.'},
#    {'from': 'gpt',
#     'value': 'football player has scored a staggering goals and provided assists during games for real'}]},
#  {'id': 'GCC_train_002147564',
#   'image': 'GCC_train_002147564.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Give a short and clear explanation of the subsequent image.\n'},
#    {'from': 'gpt',
#     'value': 'stylish star : was clearly in the mood to relax on monday as she wore the navy sleeveless top with chic loose trousers which were adorned with a blue and white floral pattern'}]},
#  {'id': 'GCC_train_000503785',
#   'image': 'GCC_train_000503785.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'sweet pixie and mod headband is a perfect updated take on - era beauty .'}]},
#  {'id': 'GCC_train_002278964',
#   'image': 'GCC_train_002278964.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt',
#     'value': 'a white rail fence and small covered bridge near the town of a city'}]},
#  {'id': 'GCC_train_002455603',
#   'image': 'GCC_train_002455603.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt', 'value': 'no worry of waiting on a busy night .'}]},
#  {'id': 'GCC_train_001749371',
#   'image': 'GCC_train_001749371.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nProvide a brief description of the given image.'},
#    {'from': 'gpt',
#     'value': 'if you are dreaming of simpler or off - the - grid living , a yurt is a fantastic option'}]},
#  {'id': 'GCC_train_002273644',
#   'image': 'GCC_train_002273644.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Render a clear and concise summary of the photo.\n'},
#    {'from': 'gpt',
#     'value': 'a full house looks on as players of all eras line up on the turf'}]},
#  {'id': 'GCC_train_000112109',
#   'image': 'GCC_train_000112109.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt',
#     'value': 'people hosting a birthday party for cast members'}]},
#  {'id': 'GCC_train_000511035',
#   'image': 'GCC_train_000511035.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt',
#     'value': 'the strange knee pounding exercise of holding a sideways resistance against a machine while standing on leg'}]},
#  {'id': 'GCC_train_002087354',
#   'image': 'GCC_train_002087354.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nCreate a compact narrative representing the image presented.'},
#    {'from': 'gpt',
#     'value': 'at the breakfast table ; washed down with plentiful of food'}]},
#  {'id': 'GCC_train_000545174',
#   'image': 'GCC_train_000545174.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt',
#     'value': 'go ye into all the world and preach the gospel to every creature'}]},
#  {'id': 'GCC_train_001904775',
#   'image': 'GCC_train_001904775.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Render a clear and concise summary of the photo.\n'},
#    {'from': 'gpt',
#     'value': 'recovered ? pop artist was forced to postpone the leg of her tour after she had an allergic reaction to antibiotics and had to go to hospital'}]},
#  {'id': 'GCC_train_000210883',
#   'image': 'GCC_train_000210883.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt', 'value': 'cars on the causeway leading'}]},
#  {'id': 'GCC_train_002203761',
#   'image': 'GCC_train_002203761.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Give a short and clear explanation of the subsequent image.\n'},
#    {'from': 'gpt',
#     'value': 'time lapse moving clouds reflected in the windows of the skyscraper .'}]},
#  {'id': 'GCC_train_000389824',
#   'image': 'GCC_train_000389824.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Render a clear and concise summary of the photo.\n'},
#    {'from': 'gpt', 'value': 'an extreme closeup of a zooming camera lens'}]},
#  {'id': 'GCC_train_001040916',
#   'image': 'GCC_train_001040916.jpg',
#   'conversations': [{'from': 'human',
#     'value': "Present a compact description of the photo's key features.\n"},
#    {'from': 'gpt',
#     'value': 'hand holding a piece of paper with sketchy capital letter t , isolated on white .'}]},
#  {'id': 'GCC_train_000771625',
#   'image': 'GCC_train_000771625.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt', 'value': 'a lightbulb held by hands .'}]},
#  {'id': 'GCC_train_000572859',
#   'image': 'GCC_train_000572859.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Write a terse but informative summary of the picture.\n'},
#    {'from': 'gpt', 'value': 'design concept of an office tower .'}]},
#  {'id': 'GCC_train_002220496',
#   'image': 'GCC_train_002220496.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRelay a brief, clear account of the picture shown.'},
#    {'from': 'gpt',
#     'value': 'when my friend went to the concert in fans kept coming up to her thinking she was actually country pop artist'}]},
#  {'id': 'GCC_train_002548273',
#   'image': 'GCC_train_002548273.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': 'the bodybuilder also made the rather surprising revelation that she and her first husband met each other in a car park'}]},
#  {'id': 'GCC_train_000465383',
#   'image': 'GCC_train_000465383.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt',
#     'value': 'power pole in sunset with nice clouds and a red sky .'}]},
#  {'id': 'GCC_train_002046768',
#   'image': 'GCC_train_002046768.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': 'emerald dresses for the bridesmaids with the maid of honor'}]},
#  {'id': 'GCC_train_002720437',
#   'image': 'GCC_train_002720437.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Describe the image concisely.\n'},
#    {'from': 'gpt',
#     'value': 'actor painted her digits a dark black hue for the oscars .'}]},
#  {'id': 'GCC_train_002346220',
#   'image': 'GCC_train_002346220.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nGive a short and clear explanation of the subsequent image.'},
#    {'from': 'gpt',
#     'value': "view of a mountain range through a skier 's goggles"}]},
#  {'id': 'GCC_train_000005572',
#   'image': 'GCC_train_000005572.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Write a terse but informative summary of the picture.\n'},
#    {'from': 'gpt',
#     'value': 'a silhouetted helicopter flying through brilliant orange clouds during sunrise over cape'}]},
#  {'id': 'GCC_train_001806972',
#   'image': 'GCC_train_001806972.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Share a concise interpretation of the image provided.\n'},
#    {'from': 'gpt',
#     'value': 'person , sports a green afro and beard as he watches the parade from his fathers shoulders'}]},
#  {'id': 'GCC_train_001694191',
#   'image': 'GCC_train_001694191.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': 'a close up of white geese with orange beaks in a cage'}]},
#  {'id': 'GCC_train_001994587',
#   'image': 'GCC_train_001994587.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Write a terse but informative summary of the picture.\n'},
#    {'from': 'gpt',
#     'value': '# photo of the day spacecraft manufacturer published pictures of a giant iceberg separated'}]},
#  {'id': 'GCC_train_000541969',
#   'image': 'GCC_train_000541969.jpg',
#   'conversations': [{'from': 'human',
#     'value': "Present a compact description of the photo's key features.\n"},
#    {'from': 'gpt',
#     'value': 'wish i knew who actually make this dress ... graceful dress v - neck chiffon flowing wedding dress with a high - low hem'}]},
#  {'id': 'GCC_train_000154219',
#   'image': 'GCC_train_000154219.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt', 'value': 'a barn and silos are next to a country road'}]},
#  {'id': 'GCC_train_002482772',
#   'image': 'GCC_train_002482772.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': "wearing this suit at # interview might raise a few eyebrows but you 'd certainly stand out from the crowd !"}]},
#  {'id': 'GCC_train_000390817',
#   'image': 'GCC_train_000390817.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nOffer a succinct explanation of the picture presented.'},
#    {'from': 'gpt', 'value': 'person holding a rainbow flag'}]},
#  {'id': 'GCC_train_002541681',
#   'image': 'GCC_train_002541681.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRender a clear and concise summary of the photo.'},
#    {'from': 'gpt', 'value': 'travel icons and characters in a line style .'}]},
#  {'id': 'GCC_train_000396360',
#   'image': 'GCC_train_000396360.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nGive a short and clear explanation of the subsequent image.'},
#    {'from': 'gpt',
#     'value': 'person poses for a photo during a photo session'}]},
#  {'id': 'GCC_train_002619335',
#   'image': 'GCC_train_002619335.jpg',
#   'conversations': [{'from': 'human',
#     'value': "\nPresent a compact description of the photo's key features."},
#    {'from': 'gpt',
#     'value': 'actor and businessperson attend the 55th festival screening .'}]},
#  {'id': 'GCC_train_000168494',
#   'image': 'GCC_train_000168494.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Render a clear and concise summary of the photo.\n'},
#    {'from': 'gpt', 'value': 'runners compete in a 5k at sunset .'}]},
#  {'id': 'GCC_train_002041927',
#   'image': 'GCC_train_002041927.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'award winner knocked the ball away from basketball center during the first half of their game'}]},
#  {'id': 'GCC_train_000725793',
#   'image': 'GCC_train_000725793.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nDescribe the image concisely.'},
#    {'from': 'gpt',
#     'value': 'an aerial shot of soybean field ripening at spring season , agricultural landscape'}]},
#  {'id': 'GCC_train_001958203',
#   'image': 'GCC_train_001958203.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt',
#     'value': 'at millimeters long , this fairy - fly wasp may be one of the smallest insects in the world'}]},
#  {'id': 'GCC_train_002205196',
#   'image': 'GCC_train_002205196.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt',
#     'value': 'aerial shot following vulture in the sky as it passes road in the desert with lone car passing by'}]},
#  {'id': 'GCC_train_000463572',
#   'image': 'GCC_train_000463572.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Give a short and clear explanation of the subsequent image.\n'},
#    {'from': 'gpt', 'value': 'chalkboard emblem written on a blackboard'}]},
#  {'id': 'GCC_train_000380142',
#   'image': 'GCC_train_000380142.jpg',
#   'conversations': [{'from': 'human',
#     'value': "\nPresent a compact description of the photo's key features."},
#    {'from': 'gpt', 'value': 'school girl at a school desk reading a book .'}]},
#  {'id': 'GCC_train_001899566',
#   'image': 'GCC_train_001899566.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nSummarize the visual content of the image.'},
#    {'from': 'gpt', 'value': 'novelist attends a promotion for his new book'}]},
#  {'id': 'GCC_train_002398164',
#   'image': 'GCC_train_002398164.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nSummarize the visual content of the image.'},
#    {'from': 'gpt',
#     'value': 'wild boar , piglets standing next to each other'}]},
#  {'id': 'GCC_train_000989980',
#   'image': 'GCC_train_000989980.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nSummarize the visual content of the image.'},
#    {'from': 'gpt',
#     'value': 'vector illustration of a set of seamless pattern with petroglyphs'}]},
#  {'id': 'GCC_train_001991771',
#   'image': 'GCC_train_001991771.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt',
#     'value': 'australian rules football team and players run through the banner commemorating person'}]},
#  {'id': 'GCC_train_000756421',
#   'image': 'GCC_train_000756421.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Give a short and clear explanation of the subsequent image.\n'},
#    {'from': 'gpt',
#     'value': 'isolated hexagon with a toy crank vector art illustration'}]},
#  {'id': 'GCC_train_000137909',
#   'image': 'GCC_train_000137909.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nGive a short and clear explanation of the subsequent image.'},
#    {'from': 'gpt',
#     'value': 'matte black ... wonder if i should do this to my truck'}]},
#  {'id': 'GCC_train_002551196',
#   'image': 'GCC_train_002551196.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Give a short and clear explanation of the subsequent image.\n'},
#    {'from': 'gpt',
#     'value': 'out of time street art , which has now been painted over .'}]},
#  {'id': 'GCC_train_002294197',
#   'image': 'GCC_train_002294197.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt',
#     'value': 'cute couple : radio personality joined person at the event , wearing similar sparkles'}]},
#  {'id': 'GCC_train_002569037',
#   'image': 'GCC_train_002569037.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'football player during the warm - up before second round tie'}]},
#  {'id': 'GCC_train_000152715',
#   'image': 'GCC_train_000152715.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRelay a brief, clear account of the picture shown.'},
#    {'from': 'gpt',
#     'value': 'military commander presents awards to paratroopers on a rooftop'}]},
#  {'id': 'GCC_train_000590805',
#   'image': 'GCC_train_000590805.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nDescribe the image concisely.'},
#    {'from': 'gpt',
#     'value': 'the grandeur , considering this was built in the 8th century .'}]},
#  {'id': 'GCC_train_001712934',
#   'image': 'GCC_train_001712934.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nDescribe the image concisely.'},
#    {'from': 'gpt',
#     'value': 'performers gather on stage for their final bows during rehearsals .'}]},
#  {'id': 'GCC_train_002760538',
#   'image': 'GCC_train_002760538.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nDescribe the image concisely.'},
#    {'from': 'gpt', 'value': 'can of beans and a bagel on a park bench'}]},
#  {'id': 'GCC_train_002026747',
#   'image': 'GCC_train_002026747.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt',
#     'value': 'grand plans : site sits undeveloped after plans for motels also foundered a decade ago .'}]},
#  {'id': 'GCC_train_000952612',
#   'image': 'GCC_train_000952612.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'freeze photography stunning freeze moments captured with a fast shutter'}]},
#  {'id': 'GCC_train_000635089',
#   'image': 'GCC_train_000635089.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nGive a short and clear explanation of the subsequent image.'},
#    {'from': 'gpt', 'value': 'the transformers : till all are #'}]},
#  {'id': 'GCC_train_001046567',
#   'image': 'GCC_train_001046567.jpg',
#   'conversations': [{'from': 'human',
#     'value': "\nPresent a compact description of the photo's key features."},
#    {'from': 'gpt',
#     'value': 'a white and red light house stands near the ocean'}]},
#  {'id': 'GCC_train_000279853',
#   'image': 'GCC_train_000279853.jpg',
#   'conversations': [{'from': 'human',
#     'value': "Present a compact description of the photo's key features.\n"},
#    {'from': 'gpt', 'value': 'rotating propeller through the plane window'}]},
#  {'id': 'GCC_train_001673690',
#   'image': 'GCC_train_001673690.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'view of the ocean - side cliffs and clear - blue water'}]},
#  {'id': 'GCC_train_001015674',
#   'image': 'GCC_train_001015674.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt', 'value': 'e and person vintage initials logo symbol .'}]},
#  {'id': 'GCC_train_000185280',
#   'image': 'GCC_train_000185280.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nCreate a compact narrative representing the image presented.'},
#    {'from': 'gpt',
#     'value': 'another room in the thrift store that helps person purchase goods at reduced prices and person receive needed supplies -- a double do - good .'}]},
#  {'id': 'GCC_train_000082186',
#   'image': 'GCC_train_000082186.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt', 'value': 'rim lit bicyclists in a street at sunset'}]},
#  {'id': 'GCC_train_001979948',
#   'image': 'GCC_train_001979948.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRender a clear and concise summary of the photo.'},
#    {'from': 'gpt',
#     'value': 'a political poster uses legacy to promote the party'}]},
#  {'id': 'GCC_train_001696656',
#   'image': 'GCC_train_001696656.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Share a concise interpretation of the image provided.\n'},
#    {'from': 'gpt', 'value': 'woman steering a narrowboat on a canal'}]},
#  {'id': 'GCC_train_000887420',
#   'image': 'GCC_train_000887420.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRelay a brief, clear account of the picture shown.'},
#    {'from': 'gpt',
#     'value': 'orchestra led by classical artist performs the world premiere of symphony featuring person .'}]},
#  {'id': 'GCC_train_002098596',
#   'image': 'GCC_train_002098596.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt',
#     'value': 'suspension bridge is illuminated to shine light on the crisis and show solidarity'}]},
#  {'id': 'GCC_train_001006455',
#   'image': 'GCC_train_001006455.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Render a clear and concise summary of the photo.\n'},
#    {'from': 'gpt',
#     'value': 'structure is a gallery and atelier built in thesnow country by person .'}]},
#  {'id': 'GCC_train_001043611',
#   'image': 'GCC_train_001043611.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nCreate a compact narrative representing the image presented.'},
#    {'from': 'gpt', 'value': 'new year card for year of the horse .'}]},
#  {'id': 'GCC_train_001844667',
#   'image': 'GCC_train_001844667.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Summarize the visual content of the image.\n'},
#    {'from': 'gpt',
#     'value': 'traditional ornamental floral paisley bandanna .'}]},
#  {'id': 'GCC_train_000927260',
#   'image': 'GCC_train_000927260.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nDescribe the image concisely.'},
#    {'from': 'gpt',
#     'value': 'these doors on the second floor have beautiful floral stained glass panels .'}]},
#  {'id': 'GCC_train_000749982',
#   'image': 'GCC_train_000749982.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt', 'value': 'a portrait of athlete during a photoshoot'}]},
#  {'id': 'GCC_train_001852148',
#   'image': 'GCC_train_001852148.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Render a clear and concise summary of the photo.\n'},
#    {'from': 'gpt',
#     'value': 'moody time lapse rain clouds passing over a gray mountain lake in the rain'}]},
#  {'id': 'GCC_train_000079175',
#   'image': 'GCC_train_000079175.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt',
#     'value': 'the blonde bombshell returned to filming location to play person in film of play .'}]},
#  {'id': 'GCC_train_001870179',
#   'image': 'GCC_train_001870179.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nProvide a brief description of the given image.'},
#    {'from': 'gpt', 'value': 'walking the ridge on the crater'}]},
#  {'id': 'GCC_train_002362091',
#   'image': 'GCC_train_002362091.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nOffer a succinct explanation of the picture presented.'},
#    {'from': 'gpt',
#     'value': 'the government has been pushing for green upgrades to vehicles and has set carbon - cutting targets , in response to the threat of the air becoming hazardous to residents'}]},
#  {'id': 'GCC_train_000196242',
#   'image': 'GCC_train_000196242.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Render a clear and concise summary of the photo.\n'},
#    {'from': 'gpt',
#     'value': 'illustration of a summer holiday in bright colors .'}]},
#  {'id': 'GCC_train_002615023',
#   'image': 'GCC_train_002615023.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Share a concise interpretation of the image provided.\n'},
#    {'from': 'gpt',
#     'value': 'a diverse group of people walk in a protest march'}]},
#  {'id': 'GCC_train_001018602',
#   'image': 'GCC_train_001018602.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nGive a short and clear explanation of the subsequent image.'},
#    {'from': 'gpt',
#     'value': 'the grille of automobile model is stretched wider all the way to the headlights .'}]},
#  {'id': 'GCC_train_001797773',
#   'image': 'GCC_train_001797773.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt',
#     'value': "whether you 're on the beach or raising a glass after work , these recipes will liven up your summer nights ."}]},
#  {'id': 'GCC_train_002683388',
#   'image': 'GCC_train_002683388.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt',
#     'value': 'automobile model is one of the new models that brand and venture funded company will be showing off thanks to some collaboration .'}]},
#  {'id': 'GCC_train_001727076',
#   'image': 'GCC_train_001727076.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nProvide a brief description of the given image.'},
#    {'from': 'gpt', 'value': 'opal that looks like it has captured fire .'}]},
#  {'id': 'GCC_train_000783518',
#   'image': 'GCC_train_000783518.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt',
#     'value': 'architect won the tender to build project focus .'}]},
#  {'id': 'GCC_train_001917565',
#   'image': 'GCC_train_001917565.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt',
#     'value': 'keeping up your trousers : the model appeared to hitch up her leather trousers at every pace for fear that the open back would expose her low - riding incident'}]},
#  {'id': 'GCC_train_000313806',
#   'image': 'GCC_train_000313806.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt', 'value': 'busy crowd in the souk'}]},
#  {'id': 'GCC_train_000726211',
#   'image': 'GCC_train_000726211.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nGive a short and clear explanation of the subsequent image.'},
#    {'from': 'gpt',
#     'value': 'a group of children playing ice hockey at the skating rink outside in winter'}]},
#  {'id': 'GCC_train_000104697',
#   'image': 'GCC_train_000104697.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt',
#     'value': 'issues like handling ice floes in relation to wind turbines still need to be worked out'}]},
#  {'id': 'GCC_train_001820853',
#   'image': 'GCC_train_001820853.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt', 'value': 'pop artist poses for a portrait'}]},
#  {'id': 'GCC_train_000271700',
#   'image': 'GCC_train_000271700.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Render a clear and concise summary of the photo.\n'},
#    {'from': 'gpt',
#     'value': 'corridors of uncertainty : a floor at the pegasus'}]},
#  {'id': 'GCC_train_002522266',
#   'image': 'GCC_train_002522266.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Render a clear and concise summary of the photo.\n'},
#    {'from': 'gpt',
#     'value': 'wide shot of peninsula and with a tugboat coming towards camera from a distance'}]},
#  {'id': 'GCC_train_001126050',
#   'image': 'GCC_train_001126050.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Describe the image concisely.\n'},
#    {'from': 'gpt',
#     'value': 'white arbor with red blooming roses in a garden'}]},
#  {'id': 'GCC_train_001966944',
#   'image': 'GCC_train_001966944.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt',
#     'value': 'cans of canned fruit are seen on a supermarket shelf'}]},
#  {'id': 'GCC_train_002286619',
#   'image': 'GCC_train_002286619.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRelay a brief, clear account of the picture shown.'},
#    {'from': 'gpt', 'value': 'iron helmet over a wooden tripod used to sit'}]},
#  {'id': 'GCC_train_002265410',
#   'image': 'GCC_train_002265410.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRender a clear and concise summary of the photo.'},
#    {'from': 'gpt', 'value': 'she turns heads at every red carpet event .'}]},
#  {'id': 'GCC_train_000607012',
#   'image': 'GCC_train_000607012.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Give a short and clear explanation of the subsequent image.\n'},
#    {'from': 'gpt', 'value': 'an ornament in east style .'}]},
#  {'id': 'GCC_train_000635013',
#   'image': 'GCC_train_000635013.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt', 'value': 'spider waiting for the kill'}]},
#  {'id': 'GCC_train_002373323',
#   'image': 'GCC_train_002373323.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt', 'value': 'actor attends person at press event'}]},
#  {'id': 'GCC_train_002244766',
#   'image': 'GCC_train_002244766.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nDescribe the image concisely.'},
#    {'from': 'gpt', 'value': 'private meeting : met the pope in may'}]},
#  {'id': 'GCC_train_000056311',
#   'image': 'GCC_train_000056311.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt',
#     'value': 'suspicious men in black hat and cloak coming out of the darkness'}]},
#  {'id': 'GCC_train_001072160',
#   'image': 'GCC_train_001072160.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nGive a short and clear explanation of the subsequent image.'},
#    {'from': 'gpt', 'value': 'a bobcat hides on a tree branch'}]},
#  {'id': 'GCC_train_000324776',
#   'image': 'GCC_train_000324776.jpg',
#   'conversations': [{'from': 'human',
#     'value': "\nPresent a compact description of the photo's key features."},
#    {'from': 'gpt', 'value': 'blue rally car in a race'}]},
#  {'id': 'GCC_train_000580662',
#   'image': 'GCC_train_000580662.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Summarize the visual content of the image.\n'},
#    {'from': 'gpt', 'value': 'red tomato in a stainless steel pot'}]},
#  {'id': 'GCC_train_001659667',
#   'image': 'GCC_train_001659667.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRender a clear and concise summary of the photo.'},
#    {'from': 'gpt',
#     'value': 'dressing down : person looked casual in a loose black sweater , skinny jeans and black ankle boots'}]},
#  {'id': 'GCC_train_000040558',
#   'image': 'GCC_train_000040558.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Describe the image concisely.\n'},
#    {'from': 'gpt',
#     'value': 'matchday mascots pose for a photo before the game against rugby union team'}]},
#  {'id': 'GCC_train_002735856',
#   'image': 'GCC_train_002735856.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRender a clear and concise summary of the photo.'},
#    {'from': 'gpt', 'value': 'animal in the night wallpaper'}]},
#  {'id': 'GCC_train_002109690',
#   'image': 'GCC_train_002109690.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': "it 's appropriate for teens to want to spend more time with their peers than their parents as they get older ."}]},
#  {'id': 'GCC_train_002252234',
#   'image': 'GCC_train_002252234.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'person a rescue dog watching dragonflies for hours .'}]},
#  {'id': 'GCC_train_000160891',
#   'image': 'GCC_train_000160891.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt', 'value': 'close - up of a businessman holding an abacus'}]},
#  {'id': 'GCC_train_001973067',
#   'image': 'GCC_train_001973067.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nOffer a succinct explanation of the picture presented.'},
#    {'from': 'gpt',
#     'value': 'the baptism of the imperial prince in the cathedral the page'}]},
#  {'id': 'GCC_train_001778967',
#   'image': 'GCC_train_001778967.jpg',
#   'conversations': [{'from': 'human',
# ...
#   'conversations': [{'from': 'human',
#     'value': "Present a compact description of the photo's key features.\n"},
#    {'from': 'gpt',
#     'value': 'on a mission : synthpop artist walked with determination as she left the studios in her super high shoes'}]},
#  {'id': 'GCC_train_001727873',
#   'image': 'GCC_train_001727873.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nDescribe the image concisely.'},
#    {'from': 'gpt', 'value': 'many dollar bills in a mousetrap'}]},
#  {'id': 'GCC_train_002372265',
#   'image': 'GCC_train_002372265.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nSummarize the visual content of the image.'},
#    {'from': 'gpt', 'value': 'throw a fur vest on with a beanie'}]},
#  {'id': 'GCC_train_000650953',
#   'image': 'GCC_train_000650953.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt',
#     'value': 'flying over desert landscape covered in tire tracks past cliff face in the badlands'}]},
#  {'id': 'GCC_train_001944765',
#   'image': 'GCC_train_001944765.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Share a concise interpretation of the image provided.\n'},
#    {'from': 'gpt', 'value': 'and person , world cultural heritage'}]},
#  {'id': 'GCC_train_000204238',
#   'image': 'GCC_train_000204238.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Give a short and clear explanation of the subsequent image.\n'},
#    {'from': 'gpt',
#     'value': 'food and drink , seasonal autumn thanksgiving holidays concept .'}]},
#  {'id': 'GCC_train_002154425',
#   'image': 'GCC_train_002154425.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'person is surrounded by her teammates on the girls soccer team as she signs her letter of intent during a ceremony at the school wednesday .'}]},
#  {'id': 'GCC_train_000785099',
#   'image': 'GCC_train_000785099.jpg',
#   'conversations': [{'from': 'human',
#     'value': "Present a compact description of the photo's key features.\n"},
#    {'from': 'gpt',
#     'value': 'family clothing stores business sparked fury after an advert referred to boyssocial butterflies'}]},
#  {'id': 'GCC_train_001008327',
#   'image': 'GCC_train_001008327.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt',
#     'value': "american football player watches the replay as he sees that sports team have scored their second touchdown in the second quarter of sunday 's game ."}]},
#  {'id': 'GCC_train_001957191',
#   'image': 'GCC_train_001957191.jpg',
#   'conversations': [{'from': 'human',
#     'value': "Present a compact description of the photo's key features.\n"},
#    {'from': 'gpt',
#     'value': 'a fisherman attaches a hook to a catfish to be used as bait during fishing'}]},
#  {'id': 'GCC_train_002594879',
#   'image': 'GCC_train_002594879.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': 'a herd of cows which escaped from fencing damaged by person block a highway'}]},
#  {'id': 'GCC_train_002577560',
#   'image': 'GCC_train_002577560.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nProvide a brief description of the given image.'},
#    {'from': 'gpt',
#     'value': 'creative image of spilled sprinkles , with a miniature 3d printed vacuum cleaner cleaning a number by person'}]},
#  {'id': 'GCC_train_000999759',
#   'image': 'GCC_train_000999759.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Summarize the visual content of the image.\n'},
#    {'from': 'gpt', 'value': 'actor wears manufacturing business to awards'}]},
#  {'id': 'GCC_train_002149327',
#   'image': 'GCC_train_002149327.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Describe the image concisely.\n'},
#    {'from': 'gpt', 'value': 'post office in the village'}]},
#  {'id': 'GCC_train_002071397',
#   'image': 'GCC_train_002071397.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nSummarize the visual content of the image.'},
#    {'from': 'gpt',
#     'value': 'paper on the wall for written communication in the workplace .'}]},
#  {'id': 'GCC_train_000003838',
#   'image': 'GCC_train_000003838.jpg',
#   'conversations': [{'from': 'human',
#     'value': "\nPresent a compact description of the photo's key features."},
#    {'from': 'gpt',
#     'value': 'breakfast - a plate of pastries and croissants'}]},
#  {'id': 'GCC_train_000937271',
#   'image': 'GCC_train_000937271.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt',
#     'value': 'baby boy wearing a hat lays in a basket during a newborn photo session'}]},
#  {'id': 'GCC_train_000100165',
#   'image': 'GCC_train_000100165.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'white lilies bunch isolated on a white background'}]},
#  {'id': 'GCC_train_002736710',
#   'image': 'GCC_train_002736710.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'volley earned levelled the game deep into stoppage time'}]},
#  {'id': 'GCC_train_002516551',
#   'image': 'GCC_train_002516551.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt',
#     'value': 'defensive tackle person makes a tackle against university on saturday .'}]},
#  {'id': 'GCC_train_002310678',
#   'image': 'GCC_train_002310678.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt', 'value': 'cows on a summer meadow'}]},
#  {'id': 'GCC_train_000236407',
#   'image': 'GCC_train_000236407.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt',
#     'value': 'we can only appreciate the miracle of a sunrise if we have waited in the darkness'}]},
#  {'id': 'GCC_train_001709886',
#   'image': 'GCC_train_001709886.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nOffer a succinct explanation of the picture presented.'},
#    {'from': 'gpt',
#     'value': 'soccer ball or football bright studio on a black background .'}]},
#  {'id': 'GCC_train_001887763',
#   'image': 'GCC_train_001887763.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt',
#     'value': 'goodies : made some beautiful baskets for her children'}]},
#  {'id': 'GCC_train_000998376',
#   'image': 'GCC_train_000998376.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRelay a brief, clear account of the picture shown.'},
#    {'from': 'gpt', 'value': 'animation showing the concept of teamwork'}]},
#  {'id': 'GCC_train_002002727',
#   'image': 'GCC_train_002002727.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt',
#     'value': 'politician addresses reporters during a press conference .'}]},
#  {'id': 'GCC_train_000590953',
#   'image': 'GCC_train_000590953.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Share a concise interpretation of the image provided.\n'},
#    {'from': 'gpt', 'value': 'picture number from the photo album called'}]},
#  {'id': 'GCC_train_000351571',
#   'image': 'GCC_train_000351571.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Relay a brief, clear account of the picture shown.\n'},
#    {'from': 'gpt', 'value': 'speed limit sign at a desert road'}]},
#  {'id': 'GCC_train_002160629',
#   'image': 'GCC_train_002160629.jpg',
#   'conversations': [{'from': 'human',
#     'value': "Present a compact description of the photo's key features.\n"},
#    {'from': 'gpt',
#     'value': 'his holiness and the leaders of major religious traditions taking part in a symbolic ceremony of pouring water over a globe model .'}]},
#  {'id': 'GCC_train_001158970',
#   'image': 'GCC_train_001158970.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Give a short and clear explanation of the subsequent image.\n'},
#    {'from': 'gpt',
#     'value': 'australian local government area will be talking to both the state and federal governments about funding for the project .'}]},
#  {'id': 'GCC_train_000302327',
#   'image': 'GCC_train_000302327.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nGive a short and clear explanation of the subsequent image.'},
#    {'from': 'gpt', 'value': 'christmas reindeer on a white background'}]},
#  {'id': 'GCC_train_002055384',
#   'image': 'GCC_train_002055384.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRender a clear and concise summary of the photo.'},
#    {'from': 'gpt',
#     'value': 'politician embraces the outgoing commander as military person , chairman , looks on during a change of command ceremony'}]},
#  {'id': 'GCC_train_000656286',
#   'image': 'GCC_train_000656286.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt',
#     'value': 'glamorous shopper : pop artist , did a little retail therapy on monday night in form - fitting black evening gown and sunglasses'}]},
#  {'id': 'GCC_train_002623226',
#   'image': 'GCC_train_002623226.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Summarize the visual content of the image.\n'},
#    {'from': 'gpt', 'value': 'video of helicopter during an airshow .'}]},
#  {'id': 'GCC_train_001920943',
#   'image': 'GCC_train_001920943.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nProvide a brief description of the given image.'},
#    {'from': 'gpt', 'value': 'still life of a dish of chili coated peanuts'}]},
#  {'id': 'GCC_train_001667035',
#   'image': 'GCC_train_001667035.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Write a terse but informative summary of the picture.\n'},
#    {'from': 'gpt',
#     'value': 'seamless black lace pattern on a white background'}]},
#  {'id': 'GCC_train_002741016',
#   'image': 'GCC_train_002741016.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt',
#     'value': 'stylish : actor showed off her unique style in a layered black frock with sheer sleeves and panels on her ribs'}]},
#  {'id': 'GCC_train_002114414',
#   'image': 'GCC_train_002114414.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': 'rhythm and blues artist performs with person on the main stage on day in the isle'}]},
#  {'id': 'GCC_train_002163902',
#   'image': 'GCC_train_002163902.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Render a clear and concise summary of the photo.\n'},
#    {'from': 'gpt', 'value': 'cup icon on the white background .'}]},
#  {'id': 'GCC_train_001744679',
#   'image': 'GCC_train_001744679.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Describe the image concisely.\n'},
#    {'from': 'gpt',
#     'value': 'greetings cards for birthday - hope you have the brightest of birthdays !'}]},
#  {'id': 'GCC_train_001744486',
#   'image': 'GCC_train_001744486.jpg',
#   'conversations': [{'from': 'human',
#     'value': "\nPresent a compact description of the photo's key features."},
#    {'from': 'gpt',
#     'value': 'triangular frame made of branches with roses and flower buds .'}]},
#  {'id': 'GCC_train_000351386',
#   'image': 'GCC_train_000351386.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Write a terse but informative summary of the picture.\n'},
#    {'from': 'gpt',
#     'value': 'the stone home is listed and has a total of fireplaces'}]},
#  {'id': 'GCC_train_002158938',
#   'image': 'GCC_train_002158938.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Provide a brief description of the given image.\n'},
#    {'from': 'gpt',
#     'value': 'character of an overweight woman dressed in sportswear on green background .'}]},
#  {'id': 'GCC_train_002494730',
#   'image': 'GCC_train_002494730.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Offer a succinct explanation of the picture presented.\n'},
#    {'from': 'gpt',
#     'value': 'laminate in a white oak visual inspired by mellow oil - rubbed floors .'}]},
#  {'id': 'GCC_train_002071867',
#   'image': 'GCC_train_002071867.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Write a terse but informative summary of the picture.\n'},
#    {'from': 'gpt',
#     'value': 'person contemplates the angry sea from a heavenly vantage point .'}]},
#  {'id': 'GCC_train_002125982',
#   'image': 'GCC_train_002125982.jpg',
#   'conversations': [{'from': 'human',
#     'value': "\nPresent a compact description of the photo's key features."},
#    {'from': 'gpt',
#     'value': 'bedroom apartment in the grade ii - listed 1950s'}]},
#  {'id': 'GCC_train_002487372',
#   'image': 'GCC_train_002487372.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Create a compact narrative representing the image presented.\n'},
#    {'from': 'gpt',
#     'value': 'watch out for the sweet tooth when you wear dress with candy cane striped bows .'}]},
#  {'id': 'GCC_train_002695910',
#   'image': 'GCC_train_002695910.jpg',
#   'conversations': [{'from': 'human',
#     'value': "Present a compact description of the photo's key features.\n"},
#    {'from': 'gpt',
#     'value': 'peasant woman , old photographs beginning of the twentieth century'}]},
#  {'id': 'GCC_train_000147681',
#   'image': 'GCC_train_000147681.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nWrite a terse but informative summary of the picture.'},
#    {'from': 'gpt',
#     'value': 'the period style property has been modernised throughout inside by the current owners'}]},
#  {'id': 'GCC_train_002684360',
#   'image': 'GCC_train_002684360.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Summarize the visual content of the image.\n'},
#    {'from': 'gpt',
#     'value': 'electrician working on a circuit board in electric room'}]},
#  {'id': 'GCC_train_000292987',
#   'image': 'GCC_train_000292987.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nRelay a brief, clear account of the picture shown.'},
#    {'from': 'gpt',
#     'value': 'vector illustration of the knight in a futuristic armor .'}]},
#  {'id': 'GCC_train_002608796',
#   'image': 'GCC_train_002608796.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nCreate a compact narrative representing the image presented.'},
#    {'from': 'gpt',
#     'value': 'very high quality original trendy vector realistic illustration of a beach ball'}]},
#  {'id': 'GCC_train_000073450',
#   'image': 'GCC_train_000073450.jpg',
#   'conversations': [{'from': 'human',
#     'value': '\nShare a concise interpretation of the image provided.'},
#    {'from': 'gpt', 'value': 'man on a lawn mower'}]},
#  {'id': 'GCC_train_002802075',
#   'image': 'GCC_train_002802075.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Share a concise interpretation of the image provided.\n'},
#    {'from': 'gpt',
#     'value': 'songwriter performs onstage during day of festival'}]},
#  {'id': 'GCC_train_002222870',
#   'image': 'GCC_train_002222870.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Summarize the visual content of the image.\n'},
#    {'from': 'gpt', 'value': 'iguana sitting by the swimming pool'}]},
#  {'id': 'GCC_train_000011878',
#   'image': 'GCC_train_000011878.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Write a terse but informative summary of the picture.\n'},
#    {'from': 'gpt', 'value': 'coffin loaded onto a train'}]},
#  {'id': 'GCC_train_000083780',
#   'image': 'GCC_train_000083780.jpg',
#   'conversations': [{'from': 'human',
#     'value': 'Give a short and clear explanation of the subsequent image.\n'},
#    {'from': 'gpt', 'value': 'tattoos - day of the dead - 103763'}]},
#  ...]

# %%
# Function to replace "from" values
def replace_from(data):
    for item in data:
        for conversation in item["conversations"]:
            if conversation["from"] == "human":
                conversation["from"] = "user"
            elif conversation["from"] == "gpt":
                conversation["from"] = "assistant"
            # rename keys
            conversation["role"] = conversation.pop("from")
            conversation["content"] = conversation.pop("value")
    return data

# Replace the "from" values
updated_data = replace_from(data)

# %%
# Write the updated data to a JSON file
with open('/home/zhangwei/MiniCPM-V/datasets/LLaVA-CC3M-Pretrain-595K/updated_chat.json', 'w') as file:
    json.dump(updated_data, file, indent=4)

print("Data has been updated and written to updated_chat.json")
# Out:
# Data has been updated and written to updated_chat.json

# %%
# Write the updated data to a JSON file
with open('/home/zhangwei/MiniCPM-V/datasets/LLaVA-CC3M-Pretrain-595K/updated_chat_10k.json', 'w') as file:
    json.dump(updated_data[:10000], file, indent=4)

print("Data has been updated and written to updated_chat.json")
# Out:
# Data has been updated and written to updated_chat.json

# %%
# Write the updated data to a JSON file
with open('/home/zhangwei/MiniCPM-V/datasets/LLaVA-CC3M-Pretrain-595K/updated_chat_1k.json', 'w') as file:
    json.dump(updated_data[10000:11000], file, indent=4)

print("Data has been updated and written to updated_chat.json")
# Out:
# Data has been updated and written to updated_chat.json
